# %% [markdown]
# # Module 2 Color Exercise
#
# **In these exercises, we will create plots with correct and adequate color schemes similar to the practice.**

# %%
library(ggplot2)
library(RColorBrewer)

# %% [markdown]
# **Activity 1:** Display colormaps with seven colors from RColorBrewer library for a **sequential** data type with **colorblind safe** colors.

# %%
## Your answer for activity 1 goes here ---
display.brewer.all(n=7, type="seq", colorblindFriendly=TRUE)
# Out:
# plot without title

# %% [markdown]
# **Activity 2:** Create a **colorblind safe colormap with 100 colors** from the dichromat library, and display their hexadecimal codes.

# %%
install.packages("dichromat", repo="https://cloud.r-project.org")
# Out:
# The downloaded binary packages are in
# 	/var/folders/65/317ql1jn3dd3r08f89j4z62c0000gn/T//Rtmp5suGs2/downloaded_packages

# %%
library(dichromat)
## Your answer for activity 2 goes here ---
n <- colorRampPalette(brewer.pal(11, "RdYlBu"))(100)
rgb_components <- col2rgb(n)
hexadec_codes <- rgb(rgb_components[1, ], rgb_components[2, ], rgb_components[3, ], maxColorValue = 255)
hexadec_codes
# Out:
#   [1] "#A50026" "#AA0426" "#AF0926" "#B40E26" "#B91326" "#BE1826" "#C31D26"
#   [8] "#C82126" "#CD2626" "#D22B26" "#D73027" "#DA362A" "#DD3C2C" "#E0432F"
#  [15] "#E34932" "#E54F35" "#E85538" "#EB5B3B" "#EE613D" "#F16840" "#F46E43"
#  [22] "#F57446" "#F67B49" "#F6824C" "#F7884F" "#F88F52" "#F99555" "#FA9C58"
#  [29] "#FBA25B" "#FCA95E" "#FDAF62" "#FDB467" "#FDB96B" "#FDBE70" "#FDC375"
#  [36] "#FDC87A" "#FDCD7E" "#FDD283" "#FDD788" "#FDDC8D" "#FEE191" "#FEE496"
#  [43] "#FEE79B" "#FEEAA0" "#FEEDA4" "#FEF0A9" "#FEF4AE" "#FEF7B3" "#FEFAB7"
#  [50] "#FEFDBC" "#FDFEC1" "#FAFDC7" "#F7FBCD" "#F4FAD3" "#F0F9D8" "#EDF8DE"
#  [57] "#EAF7E4" "#E7F5EA" "#E4F4EF" "#E1F3F5" "#DCF1F7" "#D7EEF5" "#D2ECF4"
#  [64] "#CCE9F2" "#C7E6F1" "#C2E4EF" "#BCE1EE" "#B7DFEC" "#B1DCEA" "#ACD9E9"
#  [71] "#A7D5E7" "#A1D1E4" "#9CCDE2" "#96C8E0" "#90C4DD" "#8BBFDB" "#85BBD8"
#  [78] "#80B6D6" "#7AB2D3" "#75ADD1" "#70A8CE" "#6BA2CB" "#669DC8" "#6197C5"
# ...

# %% [markdown]
# **Activity 3:** Use ellipse library to create an elliptical correlation plot for the diamonds data using carat, price, table, and depth variables. Make sure to use a **colorblind safe, diverging** color scheme.

# %%
install.packages("ellipse")
# Out:
# The downloaded binary packages are in
# 	/var/folders/65/317ql1jn3dd3r08f89j4z62c0000gn/T//Rtmp5suGs2/downloaded_packages

# %%
install.packages("ggplot2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/65/317ql1jn3dd3r08f89j4z62c0000gn/T//Rtmp5suGs2/downloaded_packages

# %%
update.packages(ask = FALSE, checkBuilt = TRUE)
# Out:
# The downloaded binary packages are in
# 	/var/folders/65/317ql1jn3dd3r08f89j4z62c0000gn/T//Rtmp5suGs2/downloaded_packages

# %%
install.packages("car")
# Out:
# also installing the dependencies ‘SparseM’, ‘MatrixModels’, ‘minqa’, ‘nloptr’, ‘carData’, ‘abind’, ‘pbkrtest’, ‘quantreg’, ‘lme4’
# The downloaded binary packages are in
# 	/var/folders/65/317ql1jn3dd3r08f89j4z62c0000gn/T//Rtmp5suGs2/downloaded_packages

# %%
library(ellipse)
library(ggplot2)
library(car)
library(RColorBrewer)
head(diamonds)
data = ("diamonds")


## Your answer for activity 3 goes here ---
variables <- diamonds[, c("carat", "price", "table", "depth")]
cor_matrix <- cor(variables)
color_palette <- brewer.pal(11, "RdYlBu")
ggplot(variables, aes(x = carat, y = price)) +
  geom_point(alpha = 0.7) +
  stat_ellipse(type = "t", level = 0.95, color = color_palette[3]) +
  theme_minimal() +
  labs(title = "Elliptical Correlation Plot for Diamonds Data",
       x = "Carat",
       y = "Price",
       caption = "Diverging Color Scheme")
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# plot without title

# %% [markdown]
# **Activity 4:** Create a scatter plot using **all** diamonds data for carat vs. price and encode `clarity` variable with a **sequential** color scheme.

# %%
## Your answer for activity 4 goes here ---
ggplot(diamonds, aes(x = carat, y = price, color = clarity)) +
  geom_point(alpha = 0.7) +
  scale_color_brewer(type = "seq", palette = "Blues") +
  theme_minimal() +
  labs(title = "Scatter Plot of Carat vs. Price with Clarity Encoding",
       x = "Carat",
       y = "Price",
       color = "Clarity")
# Out:
# plot without title

# %% [markdown]
# **Activity 5:** Repeat Activity 4 with **alpha transparency**. **Is this a better idea? Discuss your answer.**

# %%
## Your answer for activity 5 goes here ---
ggplot(diamonds, aes(x = carat, y = price, color = clarity)) +
  geom_point(alpha = 0.5) +  
  scale_color_brewer(type = "seq", palette = "Blues") +
  theme_minimal() +
  labs(title = "Scatter Plot of Carat vs. Price with Clarity Encoding",
       x = "Carat",
       y = "Price",
       color = "Clarity")

# hint: geom_point(alpha=0.5)

## The level of transparency can be adjusted based on the density of the data points and the visual effect you want to achieve.
# Out:
# plot without title

# %% [markdown]
# **Activity 6:** Recreate the following plot using `ggplot2` functions and the **mtcars** data set.
#
# Hint: you may have to change attribute characteristics, also look at theme functions in `ggplot2`.
#
# ![ex.png](attachment:00550901-753c-4e9b-a971-71d00e25e17d.png)

# %%
## Your answer for activity 6 goes here ---

data(mtcars)
ggplot(mtcars, aes(x = wt, y = mpg, color = factor(cyl))) +
  geom_point(aes(size = qsec)) +
  geom_smooth(data = subset(mtcars, cyl == 4), method = "lm", se = FALSE, aes(color = factor(cyl)), show.legend = FALSE) +
  geom_smooth(data = subset(mtcars, cyl == 6), method = "lm", se = FALSE, aes(color = factor(cyl)), show.legend = FALSE) +
  geom_smooth(data = subset(mtcars, cyl == 8), method = "lm", se = FALSE, aes(color = factor(cyl)), show.legend = FALSE) +
  scale_color_manual(values = c("red", "green", "blue")) +
  scale_size_continuous(range = c(2, 8)) +
  labs(x = "Weight", y = "Miles per Gallon") +
  theme_minimal()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %% [markdown]
# # Please Save the file, then submit to Blackboard (File -> Save Notebook)
